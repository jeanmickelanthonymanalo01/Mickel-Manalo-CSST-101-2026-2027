# %% [markdown]
# # My First R Program

# %% [markdown]
# ### 1. print

# %%
print("I Love R programming")
cat ("R", "Program")
# Out:
# [1] "I Love R programming"

# %% [markdown]
# 2. Variables & Data Types

# %%
myString = "My Program"
wholeNum <- 10
floatingNum <- 9.9
isBool <- TRUE

print(myString)
print(wholeNum)
print(floatingNum)
print(isBool)


class(myString)
class(wholeNum)
class(floatingNum)
class(isBool)
# Out:
# [1] "My Program"
# [1] 10
# [1] 9.9
# [1] TRUE
# [1] "character"
# [1] "numeric"
# [1] "numeric"
# [1] "logical"

# %% [markdown]
# 3. Numerical Errors

# %%
x <- 10
y <- 3


add <- x + y
sub <- x - y
mul <- x * y
div <- x / y
mod <- x %% y
exp <- x ^ y

print(add) #+
print(sub) #-
print(mul) #*
print(div) #/
print(mod) #%%
print(exp) #^
# Out:
# [1] 13
# [1] 7
# [1] 30
# [1] 3.333333
# [1] 1
# [1] 1000

# %% [markdown]
# 4. User Input

# %%
name <- readline("Enter your name: ")
cat("Welcome to R Programming Mr/Mrs: ", name)
# Out:
# Enter your name: mickey
# Welcome to R Programming Mr/Mrs:  mickey

# %% [markdown]
# 5. Decision Making

# %%
grade <- 90

if (grade < 75)(
  print("Failed")
)else(
  print("Passed")
)
# Out:
# [1] "Passed"
# [1] "Passed"

# %% [markdown]
# 6. Loop

# %%
for (i in 5:10) {
  cat("\n", i)
}
# Out:
#  5
#  6
#  7
#  8
#  9
#  10

# %% [markdown]
# 7.Functions

# %%
addNum <- function (num1, num2) {
  return (num1 + num2)
}

cat (addNum(5,10))
# Out:
# 15

# %% [markdown]
# 8. Vectors

# %%
grades <- c(90,98,89,97,80)

grades

mean(grades)
max(grades)
min(grades)
length(grades)
median(grades)
summary(grades)
# Out:
# [1] 90 98 89 97 80
# [1] 90.8
# [1] 98
# [1] 80
# [1] 5
# [1] 90
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    80.0    89.0    90.0    90.8    97.0    98.0

# %% [markdown]
# 9. Matrices

# %%
A <- matrix(c(1,2,3,4,5,6,7,8,9),nrow=3)
A
# Out:
#      [,1] [,2] [,3]
# [1,] 1    4    7
# [2,] 2    5    8
# [3,] 3    6    9

# %% [markdown]
# 10.Lists

# %%
student <- list(
  Name = "Mickey Matalo",
  Course = "BSCS",
  Section = "3-A",
  Grade = 90
)
print(student)
# Out:
# $Name
# [1] "Mickey Matalo"
#
# $Course
# [1] "BSCS"
#
# $Section
# [1] "3-A"
#
# $Grade
# [1] 90

# %% [markdown]
# 11.Dataframe

# %%
students <- data.frame(
  Name = c("Mickey", "Chunky", "ChubChub"),
  Course = c("BSCS", "BSIT", "BSA"),
  grade = c(90,98,87)
)
print(students)
# Out:
#       Name Course grade
# 1   Mickey   BSCS    90
# 2   Chunky   BSIT    98
# 3 ChubChub    BSA    87

# %% [markdown]
# 12.Write to CSV

# %%
write.csv(students, "1-12 Students.csv")

# %% [markdown]
# 13. Read CSV file

# %%
data <- read.csv("1-12 Students.csv")

head(data)
summary(data)
# Out:
#   X Name     Course grade
# 1 1 Mickey   BSCS   90
# 2 2 Chunky   BSIT   98
# 3 3 ChubChub BSA    87
#        X              Name         Course      grade
#  Min.   :1.0   Length   :3   Length   :3   Min.   :87.00
#  1st Qu.:1.5   N.unique :3   N.unique :3   1st Qu.:88.50
#  Median :2.0   N.blank  :0   N.blank  :0   Median :90.00
#  Mean   :2.0   Min.nchar:6   Min.nchar:3   Mean   :91.67
#  3rd Qu.:2.5   Max.nchar:8   Max.nchar:4   3rd Qu.:94.00
#  Max.   :3.0                               Max.   :98.00

# %% [markdown]
# 1. CREATING VARIABLES

# %%
attendance_rate <- 0.82
average_grade <- 0.78

# %% [markdown]
# 2.BASIC CALCULATIONS

# %%
grades <- c(85, 90, 88, 80)
weights <- c(0.20, 0.25, 0.25, 0.30)

final_grade <- sum(grades * weights)
final_grade
# Out:
# [1] 85.5

# %% [markdown]
# 3.USING COMPARISON OPERATORS

# %%
attendance <-82
grade <- 78

if (attendance < 75)(
  print("attendance is below 75")
)else(
  print("attendance is above 75")
)

if (grade < 75)(
  print("grade is below 75")
)else(
  print("grade is above 75")
)

if (attendance >= 75)(
  print("attendace is at least 75")
)else(
  print("attendance is not at least 75")
)

if (grade >= 75)(
  print("attendace is at least 75")
)else(
  print("attendance is not at least 75")
)
# Out:
# [1] "attendance is below 75"
# [1] "attendance is below 75"
# [1] "grade is below 75"
# [1] "grade is below 75"
# [1] "attendance is not at least 75"
# [1] "attendance is not at least 75"
# [1] "attendance is not at least 75"
# [1] "attendance is not at least 75"

# %% [markdown]
# 4.USING AND and OR

# %%
attendance <-82
grade <- 78

if (attendance < 75 & grade < 75)(
  print("student is at risk both are below")
)else(
  print("attendance is not at risk")
)


if (attendance < 75 | grade < 75)(
  print("attendace is at risk at least one is below")
)else(
  print("attendance is not at risk")
)
# Out:
# [1] "student is at risk both are below"
# [1] "student is at risk both are below"
# [1] "attendace is at risk at least one is below"
# [1] "attendace is at risk at least one is below"

# %% [markdown]
# 5.SIMPLE IF STATEMENT

# %%
grade <- 78

if (grade >= 75) (
  print("PASS")
)else(
  print("FAILED")
)
# Out:
# [1] "PASS"
# [1] "PASS"

# %% [markdown]
# 6.MULTIPLE CONDITIONS

# %%
grade <- 78

if(grade >= 90 && grade <= 100) {
  print("Excellent")
} else if (grade >= 85) {
  print("Very Good")
} else if (grade >= 80) {
  print("Good")
} else if (grade >= 75) {
  print("Passed")
} else {
  print("Failed")
}
# Out:
# [1] "Passed"

# %% [markdown]
# 7.CREATING FUNCTION

# %%
classify_grade <- function(score) {

if (score >= 90) {
  return("Excellent")
} else if (score >= 85) {
  return("Very Good")
} else if (score >= 80) {
  return("Good")
} else if (score >= 75) {
  return("Passed")
} else {
  return("Failed")
}

}

classify_grade(92)
classify_grade(78)
# Out:
# [1] "Excellent"
# [1] "Passed"

# %% [markdown]
# 8.CREATING A DATA FRAME

# %%
students <- data.frame(
  Student_ID = c("S001", "S002", "S003", "S004", "S005"),
  Attendance = c(95,72,88,79,68),
  Grade = c(90,70,85,77,65)
)
print(students)
# Out:
#   Student_ID Attendance Grade
# 1       S001         95    90
# 2       S002         72    70
# 3       S003         88    85
# 4       S004         79    77
# 5       S005         68    65

# %% [markdown]
# 9.ADDING A CLASSIFICATION COLUMN

# %%
students <- data.frame(
  Student_ID = c("S001", "S002", "S003", "S004", "S005"),
  Attendance = c(95,72,88,79,68),
  Grade = c(90,70,85,77,65)
)

students$Performance <- ifelse(
  students$Grade >= 80,
  "Good",
  ifelse(
    students$Grade >=75,
    "Passed",
    "Failed"
  )
)
print(students)
# Out:
#   Student_ID Attendance Grade Performance
# 1       S001         95    90        Good
# 2       S002         72    70      Failed
# 3       S003         88    85        Good
# 4       S004         79    77      Passed
# 5       S005         68    65      Failed

# %% [markdown]
# 10.CREATING A SIMPLE RULE BASED SYSTEM

# %%
students <- data.frame(
  Student_ID = c("S001", "S002", "S003", "S004", "S005"),
  Attendance = c(95,72,88,79,68),
  Grade = c(90,70,85,77,65)
)

students$Performance <- ifelse(
  students$Grade >= 80,
  "Good",
  ifelse(
    students$Grade >=75,
    "Passed",
    "Failed"
  )
)

students$Risk_Status <- ifelse(
  students$Attendance < 75 & students$Grade < 75,
  "High Risk",
  "Low Risk"
)
print(students)
# Out:
#   Student_ID Attendance Grade Performance Risk_Status
# 1       S001         95    90        Good    Low Risk
# 2       S002         72    70      Failed   High Risk
# 3       S003         88    85        Good    Low Risk
# 4       S004         79    77      Passed    Low Risk
# 5       S005         68    65      Failed   High Risk

# %% [markdown]
# 11.

# %%
students <- data.frame(
  Student_ID = c("S001", "S002", "S003", "S004", "S005"),
  Attendance = c(95,72,88,79,68),
  Grade = c(90,70,85,77,65)
)

students$Performance <- ifelse(
  students$Grade >= 80,
  "Good",
  ifelse(
    students$Grade >=75,
    "Passed",
    "Failed"
  )
)

students$Risk_Status <- ifelse(
  students$Attendance < 75 & students$Grade < 75,
  "High Risk",
  "Low Risk"
)

student_risk <- function(Attendance, grade) {
  if (Attendance < 75 & Grade < 75) {
    return("High Risk")
  } else if (Attendance < 85 | Grade < 80) {
    return("Moderate Risk")
  }else {
    return("Low Risk")
  }
}

print(students)
# Out:
#   Student_ID Attendance Grade Performance Risk_Status
# 1       S001         95    90        Good    Low Risk
# 2       S002         72    70      Failed   High Risk
# 3       S003         88    85        Good    Low Risk
# 4       S004         79    77      Passed    Low Risk
# 5       S005         68    65      Failed   High Risk

# %% [markdown]
# 12.

# %%
students <- data.frame(
  Student_ID = c("S001", "S002", "S003", "S004", "S005"),
  Attendance = c(95,72,88,79,68),
  Grade = c(90,70,85,77,65)
)

students$Performance <- ifelse(
  students$Grade >= 80,
  "Good",
  ifelse(
    students$Grade >=75,
    "Passed",
    "Failed"
  )
)

students$Risk_Status <- ifelse(
  students$Attendance < 75 & students$Grade < 75,
  "High Risk",
  "Low Risk"
)

student_risk <- function(Attendance, Grade) {
  if (Attendance <75 & Grade < 75) {
    return("High Risk")
  } else if (Attendance < 85 | Grade < 80) {
    return("Moderate Risk")
  }else {
    return("Low Risk")
  }
}

students$Risk <- mapply(
  student_risk,
  students$Attendance,
  students$Grade
)

print(students)
# Out:
#   Student_ID Attendance Grade Performance Risk_Status          Risk
# 1       S001         95    90        Good    Low Risk      Low Risk
# 2       S002         72    70      Failed   High Risk     High Risk
# 3       S003         88    85        Good    Low Risk      Low Risk
# 4       S004         79    77      Passed    Low Risk Moderate Risk
# 5       S005         68    65      Failed   High Risk     High Risk

# %% [markdown]
# 12

# %%
students <- data.frame(
  Student_ID = c("S001", "S002", "S003", "S004", "S005"),
  Attendance = c(95,72,88,79,68),
  Grade = c(90,70,85,77,65)
)

students$Performance <- ifelse(
  students$Grade >= 80,
  "Good",
  ifelse(
    students$Grade >=75,
    "Passed",
    "Failed"
  )
)

students$Risk_Status <- ifelse(
  students$Attendance < 75 & students$Grade < 75,
  "High Risk",
  "Low Risk"
)

student_risk <- function(Attendance, Grade) {
  if (Attendance <75 & Grade < 75) {
    return("High Risk")
  } else if (Attendance < 85 | Grade < 80) {
    return("Moderate Risk")
  }else {
    return("Low Risk")
  }
}

students$Risk <- mapply(
  student_risk,
  students$Attendance,
  students$Grade
)

print(students)
print(table(students$Risk))
# Out:
#   Student_ID Attendance Grade Performance Risk_Status          Risk
# 1       S001         95    90        Good    Low Risk      Low Risk
# 2       S002         72    70      Failed   High Risk     High Risk
# 3       S003         88    85        Good    Low Risk      Low Risk
# 4       S004         79    77      Passed    Low Risk Moderate Risk
# 5       S005         68    65      Failed   High Risk     High Risk
#
#     High Risk      Low Risk Moderate Risk
#             2             2             1

# %% [markdown]
# 13.

# %%
students <- data.frame(
  Student_ID = c("S001", "S002", "S003", "S004", "S005"),
  Attendance = c(95,72,88,79,68),
  Grade = c(90,70,85,77,65)
)

students$Performance <- ifelse(
  students$Grade >= 80,
  "Good",
  ifelse(
    students$Grade >=75,
    "Passed",
    "Failed"
  )
)

students$Risk_Status <- ifelse(
  students$Attendance < 75 & students$Grade < 75,
  "High Risk",
  "Low Risk"
)

student_risk <- function(Attendance, Grade) {
  if (Attendance <75 & Grade < 75) {
    return("High Risk")
  } else if (Attendance < 85 | Grade < 80) {
    return("Moderate Risk")
  }else {
    return("Low Risk")
  }
}

students$Risk <- mapply(
  student_risk,
  students$Attendance,
  students$Grade
)

risk_counts <- table(students$Risk)
barplot(
  risk_counts,
  main ="Student Risk Classification",
  xlab = "Risk Level",
  ylab = "Number of students"
)
print(students)
print(table(students$Risk))
# Out:
#   Student_ID Attendance Grade Performance Risk_Status          Risk
# 1       S001         95    90        Good    Low Risk      Low Risk
# 2       S002         72    70      Failed   High Risk     High Risk
# 3       S003         88    85        Good    Low Risk      Low Risk
# 4       S004         79    77      Passed    Low Risk Moderate Risk
# 5       S005         68    65      Failed   High Risk     High Risk
#
#     High Risk      Low Risk Moderate Risk
#             2             2             1
# Plot with title “Student Risk Classification”

# %% [markdown]
# Slide 12: Count the Results (Questions 1–4)
# •	1. How many students are High Risk? 2 students (S002 and S005)
# •	2. How many are Moderate Risk? 1 student (S004)
# •	3. How many are Low Risk? 2 students (S001 and S003)
# •	4. Which group has the largest number of students? Both High Risk and Low Risk are tied for the largest group with 2 students each.
# Slide 13: Create a Visualization (Questions 1–3)
# •	1. What does the graph show? It shows a frequency bar chart comparing the total count of students in each risk classification category.
# •	2. Which risk category has the most students? High Risk and Low Risk are tied for the highest category with 2 students each.
# •	3. What action should the university take? Provide immediate academic counseling, tutoring, and attendance monitoring for High Risk students (S002 and S005), while tracking Moderate Risk students (S004) to prevent further grade or attendance drops.

# %% [markdown]
# 14.

# %%
students <- data.frame(
  Student_ID = c("S001", "S002", "S003", "S004", "S005"),
  Attendance = c(95,72,88,79,68),
  Grade = c(90,70,85,77,65)
)

students$Performance <- ifelse(
  students$Grade >= 80,
  "Good",
  ifelse(
    students$Grade >=75,
    "Passed",
    "Failed"
  )
)

students$Risk_Status <- ifelse(
  students$Attendance < 75 & students$Grade < 75,
  "High Risk",
  "Low Risk"
)

student_risk <- function(Attendance, Grade) {
  if (Attendance <75 & Grade < 75) {
    return("High Risk")
  } else if (Attendance < 85 | Grade < 80) {
    return("Moderate Risk")
  }else {
    return("Low Risk")
  }
}

students$Risk <- mapply(
  student_risk,
  students$Attendance,
  students$Grade
)

risk_counts <- table(students$Risk)
barplot(
  risk_counts,
  main ="Student Risk Classification",
  xlab = "Risk Level",
  ylab = "Number of students"
)

get_recommendation <- function (risk) {
  if (risk == "High Risk") {
    return("Immediate academic intervention")
  } else if (risk == "Moderate Risk") {
    return("Academic Monitoring")
  } else {
    return("Continue regular monitoring")
  }
}

students$Recommendation <- mapply(get_recommendation, students$Risk)

View(students)
print(table(students$Risk))
# Out:
#   Student_ID Attendance Grade Performance Risk_Status Risk
# 1 S001       95         90    Good        Low Risk    Low Risk
# 2 S002       72         70    Failed      High Risk   High Risk
# 3 S003       88         85    Good        Low Risk    Low Risk
# 4 S004       79         77    Passed      Low Risk    Moderate Risk
# 5 S005       68         65    Failed      High Risk   High Risk
#   Recommendation
# 1 Continue regular monitoring
# 2 Immediate academic intervention
# 3 Continue regular monitoring
# 4 Academic Monitoring
# 5 Immediate academic intervention
#     High Risk      Low Risk Moderate Risk
#             2             2             1
# Plot with title “Student Risk Classification”

# %% [markdown]
# 15.

# %%
students <- data.frame(
  Student_ID = c("S001", "S002", "S003", "S004", "S005"),
  Attendance = c(95,72,88,79,68),
  Grade = c(90,70,85,77,65)
)

students$Performance <- ifelse(
  students$Grade >= 80,
  "Good",
  ifelse(
    students$Grade >=75,
    "Passed",
    "Failed"
  )
)

students$Risk_Status <- ifelse(
  students$Attendance < 75 & students$Grade < 75,
  "High Risk",
  "Low Risk"
)

student_risk <- function(Attendance, Grade) {
  if (Attendance <75 & Grade < 75) {
    return("High Risk")
  } else if (Attendance < 85 | Grade < 80) {
    return("Moderate Risk")
  }else {
    return("Low Risk")
  }
}

students$Risk <- mapply(
  student_risk,
  students$Attendance,
  students$Grade
)

get_recommendation <- function (risk) {
  if (risk == "High Risk") {
    return("Immediate academic intervention")
  } else if (risk == "Moderate Risk") {
    return("Academic Monitoring")
  } else {
    return("Continue regular monitoring")
  }
}

students$Recommendation <- mapply(get_recommendation, students$Risk)

student_id <- "S002"
student_info <- subset(students, Student_ID == student_id)

cat("Student_ID:", student_info$Student_ID, "\n")
cat("Attendance:", student_info$Attendance, "%\n")
cat("Grade:", student_info$Grade, "\n")
cat("Risk Level:", student_info$Risk, "\n")
cat("Recommendation:", student_info$Recommendation, "\n")

View(students)
print(table(students$Risk))
# Out:
# Student_ID: S002
# Attendance: 72 %
# Grade: 70
# Risk Level: High Risk
# Recommendation: Immediate academic intervention
#   Student_ID Attendance Grade Performance Risk_Status Risk
# 1 S001       95         90    Good        Low Risk    Low Risk
# 2 S002       72         70    Failed      High Risk   High Risk
# 3 S003       88         85    Good        Low Risk    Low Risk
# 4 S004       79         77    Passed      Low Risk    Moderate Risk
# 5 S005       68         65    Failed      High Risk   High Risk
#   Recommendation
# 1 Continue regular monitoring
# 2 Immediate academic intervention
# 3 Continue regular monitoring
# 4 Academic Monitoring
# 5 Immediate academic intervention
#     High Risk      Low Risk Moderate Risk
#             2             2             1

# %%
write.csv(students, "Student_Summary")
